# %% [markdown]
# # Computational Theory Problems

# %%
import numpy as np

# %% [markdown]
# ## Problem 1: Binary Words and Operations

# %% [markdown]
# ## Problem 2: Fractional Parts of Cube Roots

# %% [markdown]
# The `Parity` function implemented below was adapted from(see [GeeksforGeeks article](https://www.geeksforgeeks.org/dsa/finding-the-parity-of-a-number-efficiently/))
# to calculate the parity of a number using bitwise XOR operations.

# %%
"""Calculating the parity of a given number

This function determines whether the number of 1 bits in the binary
representation of 'x' is even or odd. It uses XOR and right-shift
operations to reduce all bits to the least significant bit,
which holds the overall parity:
     0 = even number of 1s
     1 = odd number of 1s"""
def Parity(x):
    #Bitwise operations that reduce the number of bits of a variable to the least significant bit.
    t = x ^ (x >> 1);#Variable XOR's with a right shifted version of itself to combine the bits.
    t = t ^ (t >> 2);
    t = t ^ (t >> 4);
    t = t ^ (t >> 8);
    t = t ^ (t >> 16);

    #Checking if least significant bit is 1 or 0.
    #If 1 - odd parity, if 0 - even parity.
    if (t & 1):
        return 1;
    return 0;

# %%
#Testing if parity of number is odd or even.
if(Parity(9) == 0):#If least significant bit is 0 then even parity.
    print("Even Parity");
else:
    print("Odd Parity\n");#If least significant bit is 1 then odd parity.

if(Parity(13) == 0):
    print("Even Parity");
else:
    print("Odd Parity");
# Out:
# Even Parity
# Odd Parity

# %% [markdown]
# ## Problem 3: Padding

# %% [markdown]
# ## Problem 4: Hashes

# %% [markdown]
# ## Problem 5: Passwords
