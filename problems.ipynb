# %% [markdown]
# # Computational Theory Problems

# %%
import numpy as np

# %% [markdown]
# ## Problem 1: Binary Words and Operations

# %% [markdown]
# ## Problem 2: Fractional Parts of Cube Roots

# %% [markdown]
# The `Parity` function implemented below was adapted from(see [GeeksforGeeks article](https://www.geeksforgeeks.org/dsa/finding-the-parity-of-a-number-efficiently/))
# to calculate the parity of a number using bitwise XOR operations.

# %%
"""Calculating the combined parity of 3 integers.

This function determines whether the number of 1 bits across the binary
representations of 'x, y and z' is even or odd. It uses XOR and right-shift
operations to reduce all bits to the least significant bit,
which holds the individual parity of that number:
     0 = even number of 1s
     1 = odd number of 1s
     
     The final parity result is obtained by XORing the three parity bits together:
     0 = even overall parity
     1 = odd overall parity
"""

def Parity(x, y, z):
    #Bitwise operations that reduce the number of bits of a variable to the least significant bit.
    t = x ^ (x >> 1);#Variable XOR's with a right shifted version of itself to combine the bits.
    t = t ^ (t >> 2);
    t = t ^ (t >> 4);
    t = t ^ (t >> 8);
    t = t ^ (t >> 16);

    n = y ^ (y >> 1);#Repeating same process for y
    n = n ^ (n >> 2);
    n = n ^ (n >> 4);
    n = n ^ (n >> 8);
    n = n ^ (n >> 16);

    p = z ^ (z >> 1);#Repeating same process for z
    p = p ^ (p >> 2);
    p = p ^ (p >> 4);
    p = p ^ (p >> 8);
    p = p ^ (p >> 16);

    #Checking if least significant bit for each result.
    #If 1 - odd parity, if 0 - even parity.
    if (t & 1) ^ (n & 1) ^ (p & 1):#XOR the 3 parity bits to get overall parity.
        return 1;#1 = odd parity.
    return 0;#0 = even parity.

# %%
#Testing combined parity for 3 numbers.
print("\nCalculating combined parity of 3 numbers:");
if(Parity(21, 30, 39) == 0):#If overall parity bit is 0, then even parity.
    print("Even Parity");
else:
    print("Odd Parity\n");#If overall parity bit is 1, then odd parity.
# Out:
# Calculating combined parity of 3 numbers:
# Odd Parity

# %% [markdown]
# ## Problem 3: Padding

# %% [markdown]
# ## Problem 4: Hashes

# %% [markdown]
# ## Problem 5: Passwords
